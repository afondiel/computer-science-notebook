# %% [markdown]
# Ex.1 : Data Asset eXchange

# %%
import pandas as pd

# %%
pd.options.display.max_rows = 9999

# %%
df = pd.read_csv('/content/jfk_weather_sample.csv')

# %%
df.head()
# Out:
#                    DATE HOURLYDewPointTempF  HOURLYRelativeHumidity  \
# 0  2015-07-25T13:51:00Z                  60                    46.0
# 1  2016-11-18T23:51:00Z                  34                    48.0
# 2  2013-01-06T08:51:00Z                  33                    89.0
# 3  2011-01-27T16:51:00Z                  18                    48.0
# 4  2015-01-03T12:16:00Z                  27                    61.0
#
#    HOURLYDRYBULBTEMPF  HOURLYWETBULBTEMPF HOURLYPrecip  HOURLYWindSpeed  \
# 0                83.0                68.0         0.00             13.0
# 1                53.0                44.0         0.00              6.0
# 2                36.0                35.0         0.00             13.0
# 3                36.0                30.0         0.00             14.0
# 4                39.0                34.0            T             11.0
#
#    HOURLYSeaLevelPressure  HOURLYStationPressure
# 0                   30.01                  29.99
# ...

# %%
print(df)
# Out:
#                       DATE HOURLYDewPointTempF  HOURLYRelativeHumidity  \
# 0     2015-07-25T13:51:00Z                  60                    46.0
# 1     2016-11-18T23:51:00Z                  34                    48.0
# 2     2013-01-06T08:51:00Z                  33                    89.0
# 3     2011-01-27T16:51:00Z                  18                    48.0
# 4     2015-01-03T12:16:00Z                  27                    61.0
# 5     2013-02-15T20:51:00Z                  35                    79.0
# 6     2014-03-01T02:51:00Z                   4                    51.0
# 7     2014-02-12T21:51:00Z                  14                    65.0
# 8     2014-10-11T09:51:00Z                  51                    90.0
# 9     2012-08-09T04:00:00Z                  71                    94.0
# 10    2018-07-17T13:40:00Z                  76                    79.0
# 11    2012-02-04T10:51:00Z                  19                    37.0
# ...

# %%
df.shape
# Out:
# (5727, 9)

# %%
df.describe()
# Out:
#        HOURLYRelativeHumidity  HOURLYDRYBULBTEMPF  HOURLYWETBULBTEMPF  \
# count             5576.000000         5576.000000         5573.000000
# mean                66.890065           55.601327           49.910102
# std                 20.030603           17.098442           15.933717
# min                 13.000000            5.000000            3.000000
# 25%                 51.000000           42.000000           37.000000
# 50%                 69.000000           56.000000           51.000000
# 75%                 84.000000           70.000000           64.000000
# max                100.000000           99.000000           81.000000
#
#        HOURLYWindSpeed  HOURLYSeaLevelPressure  HOURLYStationPressure
# count      5571.000000             4983.000000            5569.000000
# mean         11.190451               30.027748              29.991726
# std           6.263555                0.234345               0.238639
# ...

# %% [markdown]
# Ex.2 : Model Asset eXchange

# %%
print("Model Asset eXchange")
